# %%
import os
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from RequestGuard import RequestGuard as RG

# %%
url = "https://www.boxofficemojo.com/brand/bn4168284674/"
rg = RG(url)
if rg.can_follow_link(url):
    print("robot.txt allows scraping for this page")
# Out:
# robot.txt allows scraping for this page

# %%
r = requests.get(url)
print(r.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(r.text)
# print(soup)
container = soup.find('div', {'class': 'a-section imdb-scroll-table mojo-gutter'})
# print(container)

# %%
items = container.find_all('tr')
ranks, titles, gross, max_theaters, opening_earnings, opening_num_thtrs, release_dates, studios = [], [], [], [], [], [], [], []
for row in items[1:]:
    rank = row.find('td', class_='mojo-field-type-rank').text
    ranks.append(rank)
    title = row.find('td', class_='mojo-field-type-release').text
    titles.append(title)
    life_gross = row.find('td', class_='a-text-right mojo-field-type-money mojo-sort-column mojo-estimatable').text
    gross.append(life_gross)
    max_theater = row.find('td', class_='a-text-right mojo-field-type-positive_integer').text
    max_theaters.append(max_theater)
    opening = row.find('td', class_='a-text-right mojo-field-type-money').text
    opening_earnings.append(opening)
    opening_num_thtr = row.find('td', class_='a-text-right mojo-field-type-positive_integer').text
    opening_num_thtrs.append(opening_num_thtr)
    release_date = row.find('td', class_='mojo-field-type-date').text
    release_dates.append(release_date)
    studio = row.find('td', class_='mojo-field-type-release_studios').text.strip('\n')
    studios.append(studio)

# %%
df = pd.DataFrame({'Rank': ranks, 'Title': titles, 'Gross Income': gross, 'Max Theaters': max_theaters, 'Opening Earnings': opening_earnings, 'Opening Num Theaters': opening_num_thtrs, 'Release Dates': release_dates, 'Studio': studios})
df
# Out:
#    Rank                                              Title  Gross Income  \
# 0     1         Star Wars: Episode VII - The Force Awakens  $936,662,225
# 1     2            Star Wars: Episode VIII - The Last Jedi  $620,181,382
# 2     3                       Rogue One: A Star Wars Story  $532,177,324
# 3     4      Star Wars: Episode IX - The Rise of Skywalker  $515,202,542
# 4     5          Star Wars: Episode I - The Phantom Menace  $431,088,295
# 5     6       Star Wars: Episode III - Revenge of the Sith  $380,270,577
# 6     7  Indiana Jones and the Kingdom of the Crystal S...  $317,101,119
# 7     8                 Star Wars: Episode IV - A New Hope  $307,263,857
# 8     9       Star Wars: Episode II - Attack of the Clones  $302,191,252
# 9    10         Star Wars: Episode VI - Return of the Jedi  $252,583,617
# 10   11                            Solo: A Star Wars Story  $213,767,512
# 11   12                            Raiders of the Lost Ark  $212,222,025
# 12   13     Star Wars: Episode V - The Empire Strikes Back  $209,398,025
# 13   14                 Indiana Jones and the Last Crusade  $197,171,806
# 14   15               Indiana Jones and the Temple of Doom  $179,870,271
# 15   16              Indiana Jones and the Dial of Destiny  $174,480,468
# 16   17  Star Wars: Episode IV - A New Hope1997 Special...  $138,257,865
# 17   18                                  American Graffiti  $115,000,000
# 20        2,573      $18,782,154                2,573  Jan 20, 2012
# 21        2,111      $16,293,531                2,111  Mar 14, 1997
# 22        2,655      $22,469,932                2,655  Feb 10, 2012
# 23        3,452      $14,611,273                3,452  Aug 15, 2008
# 24        1,330       $4,347,101                1,330  Jul 16, 1982
# 25          720       $3,709,562                  720  Aug 12, 1988
# 26        1,563       $5,070,136                1,563   Aug 1, 1986
# 27        1,070       $3,766,803                1,070  Aug 13, 1982
# 28            -                -                    -   Aug 3, 1979
# 29        1,006       $3,949,478                1,006  Nov 19, 1982
# 30        2,700       $8,723,194                2,700   May 3, 2024
# 31        1,141       $3,549,243                1,141  Jun 27, 1986
# 32        3,020       $5,504,441                3,020  Jan 23, 2015
# 33          628       $1,327,451                  628  Mar 25, 1983
# 34          894       $3,209,056                  894  Mar 29, 1985
# 35           58       $1,435,259                   58   Nov 1, 2002
# 36          475       $5,100,654                  475  Apr 28, 2023
# 37          322       $1,673,731                  322   Sep 7, 2012
# 38        2,097         $611,000                2,097  Jul 10, 2020
# 39          255       $1,060,459                  255  Aug 26, 2022
# 40          844         $835,570                  844  Oct 21, 1994
# 41          685         $558,857                  685  Apr 29, 2018
# 42           14                -                   14  Sep 13, 1985
# 43            8           $1,728                    8  Sep 16, 2022
#
#                                  Studio
# 0   Walt Disney Studios Motion Pictures
# 1   Walt Disney Studios Motion Pictures
# 2   Walt Disney Studios Motion Pictures
# 3   Walt Disney Studios Motion Pictures
# 4                 Twentieth Century Fox
# 5                 Twentieth Century Fox
# 6                    Paramount Pictures
# 7                 Twentieth Century Fox
# 8                 Twentieth Century Fox
# 9                 Twentieth Century Fox
# 10  Walt Disney Studios Motion Pictures
# 11                   Paramount Pictures
# 12                Twentieth Century Fox
# 13                   Paramount Pictures
# 14                   Paramount Pictures
# 15  Walt Disney Studios Motion Pictures
# 16                Twentieth Century Fox
# 17                   Universal Pictures
# 18                Twentieth Century Fox
# 19            Metro-Goldwyn-Mayer (MGM)
# 20                Twentieth Century Fox
# 21                Twentieth Century Fox
# 22                Twentieth Century Fox
# 23                         Warner Bros.
# 24                   Paramount Pictures
# 25                   Paramount Pictures
# 26                   Universal Pictures
# 27                Twentieth Century Fox
# 28                   Universal Pictures
# 29                Twentieth Century Fox
# 30  Walt Disney Studios Motion Pictures
# 31                     TriStar Pictures
# 32  Walt Disney Studios Motion Pictures
# 33                   Paramount Pictures
# 34                Twentieth Century Fox
# 35                Twentieth Century Fox
# 36                                  N/A
# 37                   Paramount Pictures
# 38  Walt Disney Studios Motion Pictures
# 39  Walt Disney Studios Motion Pictures
# 40                   Universal Pictures
# 41                        Fathom Events
# 42                         Warner Bros.
# 43                  Rialto Distribution

# %%
df.to_csv('lucasfilm_movies.csv')
