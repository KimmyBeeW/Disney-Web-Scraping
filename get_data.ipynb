# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from RequestGuard import RequestGuard as RG

# %%
url = "https://www.boxofficemojo.com/brand/bn3732077058/"
rg = RG(url)
if rg.can_follow_link(url):
    print("robot.txt allows scraping for this page")
# Out:
# robot.txt allows scraping for this page

# %%
r = requests.get(url)
print(r.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(r.text)
# print(soup)
container = soup.find('div', {'class': 'a-section imdb-scroll-table mojo-gutter'})
print(container)
# Out:
# <div class="a-section imdb-scroll-table mojo-gutter" id="table"><div class="a-section imdb-scroll-table-inner"><table class="a-bordered a-horizontal-stripes a-size-base a-span12 mojo-body-table mojo-table-annotated"><tr><th class="a-text-right mojo-field-type-rank mojo-sortable-column a-nowrap"><span title="Rank">Rank</span>
# </th><th class="a-text-left mojo-field-type-release mojo-cell-wide mojo-sortable-column a-nowrap"><span title="Release">Release</span>
# ...

# %%
items = container.find_all('tr')
ranks, titles, box_offices, max_theaters, opening_earnings, opening_num_thtrs, release_dates, studios = [], [], [], [], [], [], [], []
for row in items[1:5]:
    rank = row.find('td', class_='mojo-field-type-rank').text
    ranks.append(rank)
    title = row.find('td', class_='mojo-field-type-release').text
    titles.append(title)
    life_gross = row.find('td', class_='a-text-right mojo-field-type-money mojo-sort-column mojo-estimatable').text
    box_offices.append(life_gross)
    max_theater = row.find('td', class_='a-text-right mojo-field-type-positive_integer').text
    max_theaters.append(max_theater)
    opening = row.find('td', class_='').text
    opening_earnings.append(opening)
    opening_num_thtr = row.find('td', class_='').text
    opening_num_thtrs.append(opening_num_thtr)
    release_date = row.find('td', class_='mojo-field-type-date').text
    release_dates.append(release_date)
    studio = row.find('td', class_='mojo-field-type-release_studios').text
    studios.append(studio)
# Out:
# <tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">1</td><td class="a-text-left mojo-field-type-release mojo-cell-wide"><a class="a-link-normal" href="/release/rl3059975681/?ref_=bo_bn_table_1">Avengers: Endgame</a></td><td class="a-text-right mojo-field-type-money mojo-sort-column mojo-estimatable">$858,373,000</td><td class="a-text-right mojo-field-type-positive_integer">4,662</td><td class="a-text-right mojo-field-type-money">$357,115,007</td><td class="a-text-right mojo-field-type-positive_integer">4,662</td><td class="a-text-left mojo-field-type-date a-nowrap"><a class="a-link-normal" href="/date/2019-04-26/?ref_=bo_bn_table_1">Apr 26, 2019</a></td><td class="a-text-left mojo-field-type-release_studios"><a class="a-link-normal" href="https://pro.imdb.com/company/co0226183/boxoffice/?view=releases&amp;ref_=mojo_bn_table_1&amp;rf=mojo_bn_table_1" rel="noopener" target="_blank">Walt Disney Studios Motion Pictures<svg class="mojo-new-window-svg" viewb
# ...

# %%
df = pd.DataFrame({'rank': ranks, 'title': titles, 'link': links})
df
